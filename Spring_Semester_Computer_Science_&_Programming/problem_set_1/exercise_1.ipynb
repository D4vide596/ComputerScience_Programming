# %% [markdown]
# # Exercise 1 — Objects, Identity, and References

# %%
a = [1 , 2]
b = a
c = [1 , 2]

# %% [markdown]
#  1. Determine whether each statement is True or False:

# %% [markdown]
# 1. a is b → True
# 2. a == b → True
# 3. a is c → False
# 4. a == c → True

# %% [markdown]
# 2. Explain each answer using the concepts of identity and equality

# %% [markdown]
# - equality:
# this checks if they have the same Data, since a, b, c have the same data they will all be equal to each-other.
# - identity:
# this checks if in the memory they have the same reference, same memory slot, since b is equal to a they have the same memory slot but c is create a part and dont have the same place.

# %% [markdown]
# 3. Use id() to verify your reasoning.

# %%
print(id(a))
print(id(b))
print(id(c))
# Out:
# 4442334720
# 4442334720
# 4427880960
