# %% [markdown]
# # Exercise 4 — Designing an O(n log n) Algorithm

# %% [markdown]
# You are given a list of integers data. Determine whether there exist two distinct elements whose sum is exactly zero.
# Example:

# %%
data = [3, -1, 4, -3, 2]
# Output: True (because 3 + (-3) = 0)

# %% [markdown]
# ### Part A — Naive Approach

# %% [markdown]
# 1. Write a naive algorithm to solve the problem.

# %%
def naive_approach(data):
    n = len(data)
    for i in range(n):
        for j in range(i+1, n):
            if data[i] + data[j] == 0:
                return True
    return False

# %%
print(naive_approach(data))
# Out:
# True

# %% [markdown]
# 2. What is its worst-case time complexity?

# %% [markdown]
# $O(n^2)$

# %% [markdown]
# 3. Explain your reasoning.

# %% [markdown]
# we dont have any number that sum togheter is 0
# or its the last two

# %% [markdown]
# ### Part B — Improved Algorithm

# %% [markdown]
# Design an algorithm whose worst-case time complexity is at most: $O(n log n)$
# You may:
# * Use sorting.
# * Use binary search.
# * Use built-in sort().

# %% [markdown]
# 1. Describe your algorithm clearly (in words or pseudocode).

# %% [markdown]
# ```text
# SORT(data)
# FOR EACH x IN data:
#     target = -x
#     IF BINARY_SEARCH(data, target) AND target IS NOT AT current_index:
#         RETURN True
# RETURN False
# ``

# %% [markdown]
# 2. Justify its asymptotic upper bound.

# %% [markdown]
# $O(n \log n)$

# %% [markdown]
# 3. Explain why it is strictly better than the naive solution.

# %% [markdown]
# if n is 1000 for the $O(n^2)$ it would be 1000000 operations instead with the $O(n \log n)$ it would be 10000 operations
