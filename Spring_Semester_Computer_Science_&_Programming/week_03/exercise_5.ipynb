# %% [markdown]
# # Exercise 5 — Growth Comparison and Dominance

# %% [markdown]
# Order the following functions from slowest growth to fastest growth:

# %% [markdown]
# $
# \begin{gathered}
# \log n \\
# n \\
# n \log n \\
# n^2 \\
# n^3 \\
# 2^n
# \end{gathered}
# $

# %% [markdown]
# Then answer:

# %% [markdown]
# 1. Is $10n^2$ asymptotically different from $n^2$? Why?

# %% [markdown]
# no they are the same because we dont consider c so its $n^2 = n^2$

# %% [markdown]
# 2. Is $n \log n$ asymptotically closer to $n$ or to $n^2$? Justify.

# %% [markdown]
# if n is 10000 then $n \log n$ is 40000 that its closer to n because n is 10000 rather than $n^2$ that its 1000000

# %% [markdown]
# 3. For very large n, which grows faster: $n^3$ or $2n$?

# %% [markdown]
# for n = 1000000 $n^3$ is $1 \times 10^{18}$ instead $2n$ is $2000000$
